# %%
import pandas as pd

# Load the dataset
data = {
    'USA State': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 
                  'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 
                  'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 
                  'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 
                  'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 
                  'Wisconsin', 'Wyoming'],
    'Total Cases': [1659936, 301513, 2508168, 1029976, 12393361, 1801735, 983652, 336722, 7758207, 3157491, 401852, 525825, 4136659, 
                    2105286, 1058274, 946564, 1787563, 1659969, 326868, 1394250, 2272428, 3142827, 1812049, 1000415, 1780715, 333758, 
                    574399, 909923, 382013, 3123426, 681525, 7122731, 3501404, 293570, 3504742, 1306350, 974924, 3565499, 443803, 
                    1857853, 282895, 2588139, 8792279, 1106483, 154009, 2315784, 1989477, 657760, 2043838, 188851],
    'Total Deaths': [21138, 1485, 33749, 13246, 104634, 15348, 12354, 3463, 90232, 43095, 2009, 5482, 42005, 26672, 10797, 10229, 
                     19133, 19163, 3110, 16928, 24858, 43284, 15428, 13474, 22778, 3712, 5063, 12126, 3099, 36266, 9236, 78103, 
                     29059, 2513, 42522, 16157, 9544, 51480, 4166, 20311, 3231, 29734, 94873, 5418, 929, 23748, 16151, 8188, 16758, 
                     2048],
    'Total Recovered': [1623935, 298902, 2461333, 1012777, 12227662, 1776536, 969400, 331696, 7612612, 3075283, 395053, 517984, 
                        4094654, None, 1031729, 934730, 1738136, 1612348, 321804, 1371142, 2241026, 3082734, 1793505, 984056, 1757937, 
                        329725, 566979, 891273, 395053, 3055814, 660313, 7014253, None, 290540, 3430857, 1288527, 956827, 3055814, 
                        439178, 1827064, None, 2548828, 8598329, 1096422, 153011, 2289616, 1960007, 644461, 2020642, 186326],
    'Active Cases': [14863, 1126, 13086, 3953, 61065, 9851, 1898, 1563, 55363, 39113, 4790, 2359, 0, 312718, 15748, 1605, 30294, 
                     28458, 1954, 6180, 6544, 16809, 3116, 2885, 0, 321, 2357, 6524, 1954, 31346, 11976, 30375, 333846, 517, 31363, 
                     1666, 8553, 31346, 459, 10478, 3652, 9577, 99077, 4643, 69, 2420, 13319, 5111, 6438, 477],
}

df = pd.DataFrame(data)

# Calculate the key metrics for each state
df['CFR'] = (df['Total Deaths'] / df['Total Cases']) * 100
df['Recovery Rate'] = (df['Total Recovered'] / df['Total Cases']) * 100
df['Active Case Percentage'] = (df['Active Cases'] / df['Total Cases']) * 100

# Display the results for each state with the key metrics
print(df[['USA State', 'CFR', 'Recovery Rate', 'Active Case Percentage']])


2)import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = {
    'USA State': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 
                  'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 
                  'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 
                  'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 
                  'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 
                  'Wisconsin', 'Wyoming'],
    'Total Cases': [1659936, 301513, 2508168, 1029976, 12393361, 1801735, 983652, 336722, 7758207, 3157491, 401852, 525825, 4136659, 
                    2105286, 1058274, 946564, 1787563, 1659969, 326868, 1394250, 2272428, 3142827, 1812049, 1000415, 1780715, 333758, 
                    574399, 909923, 382013, 3123426, 681525, 7122731, 3501404, 293570, 3504742, 1306350, 974924, 3565499, 443803, 
                    1857853, 282895, 2588139, 8792279, 1106483, 154009, 2315784, 1989477, 657760, 2043838, 188851],
    'Total Deaths': [21138, 1485, 33749, 13246, 104634, 15348, 12354, 3463, 90232, 43095, 2009, 5482, 42005, 26672, 10797, 10229, 
                     19133, 19163, 3110, 16928, 24858, 43284, 15428, 13474, 22778, 3712, 5063, 12126, 3099, 36266, 9236, 78103, 
                     29059, 2513, 42522, 16157, 9544, 51480, 4166, 20311, 3231, 29734, 94873, 5418, 929, 23748, 16151, 8188, 16758, 
                     2048],
    'Total Recovered': [1623935, 298902, 2461333, 1012777, 12227662, 1776536, 969400, 331696, 7612612, 3075283, 395053, 517984, 
                        4094654, None, 1031729, 934730, 1738136, 1612348, 321804, 1371142, 2241026, 3082734, 1793505, 984056, 1757937, 
                        329725, 566979, 891273, 395053, 3055814, 660313, 7014253, None, 290540, 3430857, 1288527, 956827, 3055814, 
                        439178, 1827064, None, 2548828, 8598329, 1096422, 153011, 2289616, 1960007, 644461, 2020642, 186326],
    'Total Tests': [9332317, 4790640, 22489035, 8036831, 202799362, 21396759, 16773196, 1026007, 66800091, 28915980, 4101166, 3301678, 
                    57898053, 21512168, 8492575, 6215342, 13675281, 18935316, 5956082, 25094995, 50416970, 28943982, 24412112, 7063623, 
                    14632189, 2789012, 5506012, 6875532, 4845153, 32419102, 8610078, 131503719, 26656056, 2462480, 24766997, 5473577, 
                    12508506, 30962562, 8808359, 18979097, 2331003, 14843622, 73904384, 9406861, 4184358, 19172533, 18887049, 7291246, 
                    19643258, 1572010],
}

df = pd.DataFrame(data)

# Bar Charts: Show total cases, deaths, and recoveries per state
plt.figure(figsize=(12, 8))

# Bar chart for Total Cases
plt.subplot(3, 1, 1)
sns.barplot(x='USA State', y='Total Cases', data=df.sort_values('Total Cases', ascending=False).head(10))
plt.title('Top 10 States by Total Cases')
plt.xticks(rotation=90)

# Bar chart for Total Deaths
plt.subplot(3, 1, 2)
sns.barplot(x='USA State', y='Total Deaths', data=df.sort_values('Total Deaths', ascending=False).head(10))
plt.title('Top 10 States by Total Deaths')
plt.xticks(rotation=90)

# Bar chart for Total Recovered
plt.subplot(3, 1, 3)
sns.barplot(x='USA State', y='Total Recovered', data=df.sort_values('Total Recovered', ascending=False).head(10))
plt.title('Top 10 States by Total Recovered')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# Scatter Plot: Visualize the relationship between Total Tests and Total Cases
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Total Tests', y='Total Cases', data=df)
plt.title('Scatter Plot: Total Tests vs Total Cases')
plt.xlabel('Total Tests')
plt.ylabel('Total Cases')
plt.show()

3)import pandas as pd

# Provided dataset
data = {
    "State": ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "Florida", "Georgia", 
              "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts", 
              "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", 
              "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", 
              "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming"],
    "Total Cases": [1659936, 301513, 2508168, 1029976, 12393361, 1801735, 983652, 336722, 7758207, 3157491, 401852, 525825, 
                    4136659, 2105286, 1058274, 946564, 1787563, 1659969, 326868, 1394250, 2272428, 3142827, 1812049, 1000415, 1780715, 
                    333758, 574399, 909923, 382013, 3123426, 681525, 7122731, 3501404, 293570, 3504742, 1306350, 974924, 3565499, 
                    443803, 1857853, 282895, 2588139, 8792279, 1106483, 154009, 2315784, 1989477, 657760, 2043838, 188851],
    "Total Deaths": [21138, 1485, 33749, 13246, 104634, 15348, 12354, 3463, 90232, 43095, 2009, 5482, 42005, 26672, 10797, 10229, 
                     19133, 19163, 3110, 16928, 24858, 43284, 15428, 13474, 22778, 3712, 5063, 12126, 3099, 36266, 9236, 78103, 
                     29059, 2513, 42522, 16157, 9544, 51480, 4166, 20311, 3231, 29734, 94873, 5418, 929, 23748, 16151, 8188, 16758, 
                     2048],
    "Total Tests": [9332317, 4790640, 22489035, 8036831, 202799362, 21396759, 16773196, 1026007, 66800091, 28915980, 4101166, 3301678, 
                    57898053, 21512168, 8492575, 6215342, 13675281, 18935316, 5956082, 25094995, 50416970, 28943982, 24412112, 7063623, 
                    14632189, 2789012, 5506012, 6875532, 4845153, 32419102, 8610078, 131503719, 26656056, 2462480, 24766997, 5473577, 
                    12508506, 30962562, 8808359, 18979097, 2331003, 14843622, 73904384, 9406861, 4184358, 19172533, 18887049, 7291246, 
                    19643258, 1572010],
    "Tests/1M pop": [1903317, 6548661, 3089698, 2663139, 5132573, 3715530, 4704585, 1053651, 3110202, 2723446, 2896566, 1847542, 
                     4569040, 3195405, 2691723, 2133427, 3060940, 4073167, 4430910, 4150897, 7314755, 2898207, 4328671, 2373410, 2384091, 
                     2609534, 2846355, 2232203, 3563370, 3649900, 4106238, 6759879, 2541556, 3231338, 2118811, 1383274, 2965691, 2418574, 
                     8314785, 3686182, 2634917, 2173560, 2548789, 2934181, 6705820, 2246206, 2480278, 4068442, 3373719, 2716174],
    "Population": [4903185, 731545, 7278717, 3017804, 39512223, 5758736, 3565287, 973764, 21477737, 10617423, 1415872, 1787065, 
                   12671821, 6732219, 3155070, 2913314, 4467673, 4648794, 1344212, 6045680, 6892503, 9986857, 5639632, 2976149, 6137428, 
                   1068778, 1934408, 3080156, 1359711, 8882190, 2096829, 19453561, 10488084, 762062, 11689100, 3956971, 4217737, 12801989, 
                   1059361, 5148714, 884659, 6829174, 28995881, 3205958, 623989, 8535519, 7614893, 1792147, 5822434, 578759]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# 1. Highest and Lowest Total Cases and Deaths
highest_cases = df.loc[df['Total Cases'].idxmax()]
lowest_cases = df.loc[df['Total Cases'].idxmin()]

highest_deaths = df.loc[df['Total Deaths'].idxmax()]
lowest_deaths = df.loc[df['Total Deaths'].idxmin()]

# 2. Highest and Lowest Testing Rates (Tests per million people)
highest_testing_rate = df.loc[df['Tests/1M pop'].idxmax()]
lowest_testing_rate = df.loc[df['Tests/1M pop'].idxmin()]

# 3. Analyze Testing vs Cases (Testing Efficiency)
df['Cases/1M pop'] = df['Total Cases'] / df['Population'] * 1e6
df['Testing Efficiency'] = df['Tests/1M pop'] / df['Cases/1M pop']  # High value means more tests per case

highest_testing_efficiency = df.loc[df['Testing Efficiency'].idxmax()]
lowest_testing_efficiency = df.loc[df['Testing Efficiency'].idxmin()]

# Output results
print("State with Highest Total Cases:")
print(highest_cases[['State', 'Total Cases']])

print("\nState with Lowest Total Cases:")
print(lowest_cases[['State', 'Total Cases']])

print("\nState with Highest Total Deaths:")
print(highest_deaths[['State', 'Total Deaths']])

print("\nState with Lowest Total Deaths:")
print(lowest_deaths[['State', 'Total Deaths']])

print("\nState with Highest Testing Rate (Tests per Million):")
print(highest_testing_rate[['State', 'Tests/1M pop']])

print("\nState with Lowest Testing Rate (Tests per Million):")
print(lowest_testing_rate[['State', 'Tests/1M pop']])

print("\nState with Highest Testing Efficiency (Tests per Case):")
print(highest_testing_efficiency[['State', 'Testing Efficiency']])

print("\nState with Lowest Testing Efficiency (Tests per Case):")
print(lowest_testing_efficiency[['State', 'Testing Efficiency']])

4)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data (Replace this with the full dataset you have)
data = {
    'USA State': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 
                  'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 
                  'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 
                  'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 
                  'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 
                  'Wisconsin', 'Wyoming'],
    'Total Cases': [1659936, 301513, 2508168, 1029976, 12393361, 1801735, 983652, 336722, 7758207, 3157491, 401852, 525825, 
                    4136659, 2105286, 1058274, 946564, 1787563, 1659969, 326868, 1394250, 2272428, 3142827, 1812049, 1000415, 1780715, 
                    333758, 574399, 909923, 382013, 3123426, 681525, 7122731, 3501404, 293570, 3504742, 1306350, 974924, 3565499, 443803, 
                    1857853, 282895, 2588139, 8792279, 1106483, 154009, 2315784, 1989477, 657760, 2043838, 188851],
    'Total Deaths': [21138, 1485, 33749, 13246, 104634, 15348, 12354, 3463, 90232, 43095, 2009, 5482, 42005, 26672, 10797, 10229, 
                     19133, 19163, 3110, 16928, 24858, 43284, 15428, 13474, 22778, 3712, 5063, 12126, 3099, 36266, 9236, 78103, 29059, 
                     2513, 42522, 16157, 9544, 51480, 4166, 20311, 3231, 29734, 94873, 5418, 929, 23748, 16151, 8188, 16758, 2048],
    'Total Recovered': [1623935, 298902, 2461333, 1012777, 12227662, 1776536, 969400, 331696, 7612612, 3075283, 395053, 517984, 
                        4094654, None, 1031729, 934730, 1738136, 1612348, 321804, 1371142, 2241026, 3082734, 1793505, 984056, 1757937, 
                        329725, 566979, 891273, 321804, 3055814, 660313, 7014253, None, 290540, 3430857, 1288527, 956827, 3430857, 439178, 
                        1827064, None, 2548828, 8598329, 1096422, 153011, 2289616, 1960007, 644461, 2020642, 186326],
    'Active Cases': [14863, 1126, 13086, 3953, 61065, 9851, 1898, 1563, 55363, 39113, 4790, 2359, 0, 312718, 15748, 1605, 
                     30294, 28458, 1954, 6180, 6544, 16809, 3116, 2885, 0, 321, 2357, 6524, 1954, 31346, 11976, 30375, 333846, 517, 
                     31363, 1666, 8553, None, 459, 10478, 3652, 9577, 99077, 4643, 69, 2420, 13319, 5111, 6438, 477],
    'Total Tests': [9332317, 4790640, 22489035, 8036831, 202799362, 21396759, 16773196, 1026007, 66800091, 28915980, 4101166, 
                    3301678, 57898053, 21512168, 8492575, 6215342, 13675281, 18935316, 5956082, 25094995, 50416970, 28943982, 
                    24412112, 7063623, 14632189, 2789012, 5506012, 6875532, 4845153, 32419102, 8610078, 131503719, 26656056, 2462480, 
                    24766997, 5473577, 12508506, 30962562, 8808359, 18979097, 2331003, 14843622, 73904384, 9406861, 4184358, 19172533, 
                    18887049, 7291246, 19643258, 1572010],
    'Population': [4903185, 731545, 7278717, 3017804, 39512223, 5758736, 3565287, 973764, 21477737, 10617423, 1415872, 1787065, 
                   12671821, 6732219, 3155070, 2913314, 4467673, 4648794, 1344212, 6045680, 6892503, 9986857, 5639632, 2976149, 
                   6137428, 1068778, 1934408, 3080156, 1359711, 8882190, 2096829, 19453561, 10488084, 762062, 11689100, 3956971, 
                   4217737, 12801989, 1059361, 5148714, 884659, 6829174, 28995881, 3205958, 623989, 8535519, 7614893, 1792147, 5822434, 
                   578759]
}

# Create DataFrame
df = pd.DataFrame(data)

# Sort states by Active Cases
df_sorted_active_cases = df[['USA State', 'Active Cases']].sort_values(by='Active Cases', ascending=False)

# Plot Active Cases across states as a bar plot
plt.figure(figsize=(12, 8))
plt.barh(df_sorted_active_cases['USA State'], df_sorted_active_cases['Active Cases'], color='skyblue')
plt.xlabel('Active Cases')
plt.ylabel('USA States')
plt.title('Active COVID-19 Cases Across States')
plt.gca().invert_yaxis()  # Invert y-axis for better visualization
plt.show()

# Heatmap: Active Cases, Total Cases, and Total Deaths across states
df_heatmap = df[['USA State', 'Active Cases', 'Total Cases', 'Total Deaths']].set_index('USA State')
plt.figure(figsize=(10, 8))
sns.heatmap(df_heatmap.corr(), annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Correlation between Active Cases, Total Cases, and Total Deaths')
plt.show()

# Rank States by Active Cases and compare with Total Cases and Deaths
print("Ranking States by Active Cases:")
print(df_sorted_active_cases[['USA State', 'Active Cases']])

# Compare Active Cases with Total Cases and Deaths for the top 5 states with the most Active Cases
top_5_states_active_cases = df_sorted_active_cases.head(5)
top_5_states_data = df[df['USA State'].isin(top_5_states_active_cases['USA State'])]
print("\nComparison of Active Cases with Total Cases and Deaths (Top 5 States):")
print(top_5_states_data[['USA State', 'Active Cases', 'Total Cases', 'Total Deaths']])

5)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data (Replace this with your actual dataset)
data = {
    'USA State': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 
                  'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 
                  'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 
                  'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 
                  'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 
                  'Wisconsin', 'Wyoming'],
    'Total Cases': [1659936, 301513, 2508168, 1029976, 12393361, 1801735, 983652, 336722, 7758207, 3157491, 401852, 525825, 
                    4136659, 2105286, 1058274, 946564, 1787563, 1659969, 326868, 1394250, 2272428, 3142827, 1812049, 1000415, 1780715, 
                    333758, 574399, 909923, 382013, 3123426, 681525, 7122731, 3501404, 293570, 3504742, 1306350, 974924, 3565499, 443803, 
                    1857853, 282895, 2588139, 8792279, 1106483, 154009, 2315784, 1989477, 657760, 2043838, 188851],
    'Total Deaths': [21138, 1485, 33749, 13246, 104634, 15348, 12354, 3463, 90232, 43095, 2009, 5482, 42005, 26672, 10797, 10229, 
                     19133, 19163, 3110, 16928, 24858, 43284, 15428, 13474, 22778, 3712, 5063, 12126, 3099, 36266, 9236, 78103, 29059, 
                     2513, 42522, 16157, 9544, 51480, 4166, 20311, 3231, 29734, 94873, 5418, 929, 23748, 16151, 8188, 16758, 2048],
    'Total Recovered': [1623935, 298902, 2461333, 1012777, 12227662, 1776536, 969400, 331696, 7612612, 3075283, 395053, 517984, 
                        4094654, None, 1031729, 934730, 1738136, 1612348, 321804, 1371142, 2241026, 3082734, 1793505, 984056, 1757937, 
                        329725, 566979, 891273, 321804, 3055814, 660313, 7014253, None, 290540, 3430857, 1288527, 956827, 3430857, 439178, 
                        1827064, None, 2548828, 8598329, 1096422, 153011, 2289616, 1960007, 644461, 2020642, 186326],
    'Active Cases': [14863, 1126, 13086, 3953, 61065, 9851, 1898, 1563, 55363, 39113, 4790, 2359, 0, 312718, 15748, 1605, 
                     30294, 28458, 1954, 6180, 6544, 16809, 3116, 2885, 0, 321, 2357, 6524, 1954, 31346, 11976, 30375, 333846, 517, 
                     31363, 1666, 8553, None, 459, 10478, 3652, 9577, 99077, 4643, 69, 2420, 13319, 5111, 6438, 477],
    'Total Tests': [9332317, 4790640, 22489035, 8036831, 202799362, 21396759, 16773196, 1026007, 66800091, 28915980, 4101166, 
                    3301678, 57898053, 21512168, 8492575, 6215342, 13675281, 18935316, 5956082, 25094995, 50416970, 28943982, 
                    24412112, 7063623, 14632189, 2789012, 5506012, 6875532, 4845153, 32419102, 8610078, 131503719, 26656056, 2462480, 
                    24766997, 5473577, 12508506, 30962562, 8808359, 18979097, 2331003, 14843622, 73904384, 9406861, 4184358, 19172533, 
                    18887049, 7291246, 19643258, 1572010],
    'Population': [4903185, 731545, 7278717, 3017804, 39512223, 5758736, 3565287, 973764, 21477737, 10617423, 1415872, 1787065, 
                   12671821, 6732219, 3155070, 2913314, 4467673, 4648794, 1344212, 6045680, 6892503, 9986857, 5639632, 2976149, 
                   6137428, 1068778, 1934408, 3080156, 1359711, 8882190, 2096829, 19453561, 10488084, 762062, 11689100, 3956971, 
                   4217737, 12801989, 1059361, 5148714, 884659, 6829174, 28995881, 3205958, 623989, 8535519, 7614893, 1792147, 5822434, 
                   578759]
}

# Create DataFrame
df = pd.DataFrame(data)

# 1. Total cases and population size
df['Cases per Million'] = df['Total Cases'] / df['Population'] * 1e6

# 2. Testing rates and case numbers
df['Tests per Million'] = df['Total Tests'] / df['Population'] * 1e6

# 3. Total deaths and recovery rates
df['Recovery Rate'] = df['Total Recovered'] / df['Total Cases'] * 100
df['Death Rate'] = df['Total Deaths'] / df['Total Cases'] * 100

# 4. Correlation analysis between the variables
correlation_matrix = df[['Total Cases', 'Population', 'Tests per Million', 'Cases per Million', 
                         'Total Deaths', 'Recovery Rate', 'Death Rate']].corr()

# Display the correlation matrix
print(correlation_matrix)

# 5. Correlation heatmap visualization
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Correlation Heatmap of Key Variables')
plt.show()
